# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
# Loading the dataset from sklearn
from sklearn.datasets import load_boston
boston=load_boston()
df=pd.DataFrame(data=boston.data, columns=boston.feature_names)
df['MEDV']=boston.target
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Visualize all the input columns with the output column.
#Write your observations based on the plots generated, how the particular input is showing effect on the output

sns.regplot(df.CRIM,df.MEDV)

# %% [markdown]
# According to the above plot, the input ZN has no correlation with the output MED
# So, it has no effect on the output.

# %%
sns.regplot(df.INDUS,df.MEDV)

# %% [markdown]
#  According to the above plot, the input INDUS has no correlation with the output MEDV.
#  So, it has no effect on the output.

# %%
sns.regplot(df.NOX,df.MEDV)

# %% [markdown]
#  According to the above plot, the input NOX has no correlation with the output MEDV.
#   So, it has no effect on the output.

# %%
sns.regplot(df.RM,df.MEDV)

# %% [markdown]
# According to the above plot, the input RM has moderately negative correlation with the output MEDV.
# So, it has moderate effect on the output.

# %%
sns.regplot(df.AGE,df.MEDV)

# %% [markdown]
# According to the above plot, the input AGE has weakly negative correlation with the output MEDV.
# So, it has little effect on the output.

# %%
sns.regplot(df.DIS,df.MEDV)

# %% [markdown]
#  According to the above plot, the input DIS has no correlation with the output MEDV.
#  So, it has no effect on the output.

# %%
sns.regplot(df.RAD,df.MEDV)

# %% [markdown]
# According to the above plot, the input RAD has no correlation with the output MEDV.
# So, it has no effect on the output.

# %%
sns.regplot(df.TAX,df.MEDV)

# %% [markdown]
# According to the above plot, the input TAX has no correlation with the output MEDV.
#  So, it has no effect on the output.

# %%
sns.regplot(df.PTRATIO,df.MEDV)

# %% [markdown]
# According to the above plot, the input PTRATIO has no correlation with the output MEDV.
#  So, it has no effect on the output.

# %%
sns.regplot(df.B,df.MEDV)

# %% [markdown]
# According to the above plot, the input B has no correlation with the output MEDV. So, it has no effect on the output.

# %%
sns.regplot(df.LSTAT,df.MEDV)

# %% [markdown]
# According to the above plot, the input LSTAT has moderately negative correlation with the output MEDV.
# So, it has moderate effect on the output.

# %%
#Remove any of the one variable from the dataset if correlation is greater than 0.9. 
df.corr()[df.corr()>0.9]
# Out:
#          CRIM   ZN  INDUS  CHAS  NOX   RM  AGE  DIS       RAD       TAX  \
# CRIM      1.0  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# ZN        NaN  1.0    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# INDUS     NaN  NaN    1.0   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# CHAS      NaN  NaN    NaN   1.0  NaN  NaN  NaN  NaN       NaN       NaN
# NOX       NaN  NaN    NaN   NaN  1.0  NaN  NaN  NaN       NaN       NaN
# RM        NaN  NaN    NaN   NaN  NaN  1.0  NaN  NaN       NaN       NaN
# AGE       NaN  NaN    NaN   NaN  NaN  NaN  1.0  NaN       NaN       NaN
# DIS       NaN  NaN    NaN   NaN  NaN  NaN  NaN  1.0       NaN       NaN
# RAD       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  1.000000  0.910228
# TAX       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  0.910228  1.000000
# PTRATIO   NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# B         NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# LSTAT     NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# MEDV      NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
#
#          PTRATIO    B  LSTAT  MEDV
# CRIM         NaN  NaN    NaN   NaN
# ZN           NaN  NaN    NaN   NaN
# INDUS        NaN  NaN    NaN   NaN
# CHAS         NaN  NaN    NaN   NaN
# NOX          NaN  NaN    NaN   NaN
# RM           NaN  NaN    NaN   NaN
# AGE          NaN  NaN    NaN   NaN
# DIS          NaN  NaN    NaN   NaN
# RAD          NaN  NaN    NaN   NaN
# TAX          NaN  NaN    NaN   NaN
# PTRATIO      1.0  NaN    NaN   NaN
# B            NaN  1.0    NaN   NaN
# LSTAT        NaN  NaN    1.0   NaN
# MEDV         NaN  NaN    NaN   1.0

# %%
df.drop('TAX',axis=1,inplace=True) #dropping RAD column
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0     18.7
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0     18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0     21.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0     21.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# ..      ...    ...   ...
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %%
#Split the data into training and test with a split ratio of 80-20
#(80% of the data into training data and 20% of the data into testing)
from sklearn.model_selection import train_test_split
X=df.drop(['MEDV'],axis=1)
y=df.MEDV
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
print('X_train: ',X_train.shape)
print('X_test: ',X_test.shape)
print('y_train: ',y_train.shape)
print('y_test: ',y_test.shape)
# Out:
# X_train:  (404, 12)
# X_test:  (102, 12)
# y_train:  (404,)
# y_test:  (102,)

# %%
#Apply feature scaling on the input columns, and build the Multiple Linear Regression Model. 
#Check the performance on training and testing. 
#Write your inferences on performance metrics and error metrics.
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_scaled=pd.DataFrame(data=sc.fit_transform(df),columns=df.columns)
df_scaled
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD   PTRATIO         B     LSTAT      MEDV
# 0    0.140214 -0.982843 -1.459000  0.441052 -1.075562  0.159686
# 1    0.557160 -0.867883 -0.303094  0.441052 -0.492439 -0.101524
# 2    0.557160 -0.867883 -0.303094  0.396427 -1.208727  1.324247
# 3    1.077737 -0.752922  0.113032  0.416163 -1.361517  1.182758
# 4    1.077737 -0.752922  0.113032  0.441052 -1.026501  1.487503
#        23.23781859, 40.52375342, 20.88935777, 35.4911899 , 13.72994204,
#        18.10762621, 24.17551878, 30.63746487, 30.75862275, 10.4980765 ,
#        17.23046453, 18.81565418, 18.15372145, 19.45798011, 26.15159373,
#        27.85870668, 23.4549454 , 20.79511233, 12.58626406, 14.92405435,
#        16.81701709, 18.74978381, 20.96726267, 31.19894903, 32.82125903,
#        24.52013795, 22.88869415, 35.25344351, 27.80479334, 13.12981204,
#        18.83367419,  2.56532263, 27.96606067, 21.21549802, 29.08499364,
#        23.24694388, 17.81337383, 11.449553  , 32.90343214, 23.9008364 ,
#        22.84950482, 22.13505714,  6.85192975, 19.82796332, 19.00896699,
#        11.55933448, 24.9451268 , 16.15291792, 27.49353472, 20.18805626,
#        16.05456359, 21.65487584, 11.00816911, 19.16573699, 24.87406659,
#        21.25165443, 33.88526668, 33.235528  , 17.00854033, 12.48965503,
#        14.62163591, 23.45622285, 20.58338865, 33.46169415, 20.18917317,
#        20.16618988, 17.14569976, 24.42142416, 25.41669802, 21.56345697,
#        23.41457243, 18.15740995, 20.92994055, 21.7076351 ])

# %%
#Checking the performance on both using r2_score and Adjusted r2_score:
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('Training :')

print('R^2:', r2_score(y_train,y_train_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_train, y_train_pred))*(len(X_train)-1)/
      (len(X_train)-X_train.shape[1]-1))
print('MAE: ',mean_absolute_error(y_train,y_train_pred))
print('MSE: ',mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_train,y_train_pred)))

print('Test :')

print('R^2:', r2_score(y_test,y_test_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_test, y_test_pred))*(len(X_test)-1)/
      (len(X_test)-X_test.shape[1]-1))
print('MAE: ',mean_absolute_error(y_test,y_test_pred))
print('MSE ',mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# Training :
# R^2: 0.7464095280063323
# Adjusted R^2: 0.7386267002213605
# MAE:  3.108764344131646
# MSE:  19.581616289384222
# RMSE:  4.425112008682291
# Test :
# R^2: 0.6964348052593579
# Adjusted R^2: 0.6555046666426421
# MAE:  4.080980967181372
# MSE  34.05734246080102
# RMSE:  5.835866898824974

# %% [markdown]
# # Training:
#     -R2: indicates 74% accuracy
#     -adjusted R2: indicates 73% accuracy
# # Testing:
#     -RMSE is 4.42,error of 4.6 in the predicted values
#     -The accuracy of the model on predicting the trained data is 73% and the error caused while
#     predicting these values is around 4.42
#
#
# # Training:
#     -R2: indicates 69% accuracy
#     -adjusted R2: indicates 65% accuracy
# # Testing:
#     -The RMSE is 5.83,error of 5.86 in the predicted values
#     -The accuracy of the model on predicting the trained data is 69% and the error caused while
#     predicting these values is around 5.83
