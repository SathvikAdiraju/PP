# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('assign.csv')

# %%
df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 10 columns]

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose
# 0           6             radio/TV
# 1          48             radio/TV
# 2          12            education
# 3          42  furniture/equipment
# 4          24                  car
# ..        ...                  ...
# 995        12  furniture/equipment
# 996        30                  car
# 997        12             radio/TV
# 998        45             radio/TV
# 999        45                  car
#
# [1000 rows x 9 columns]

# %%
#Check the data types and get the summary stats
#datatypes
df.dtypes
# Out:
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
#summary stats
df.describe()
# Out:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
#summary stats of categorical
df.describe(include='object')
# Out:
#          Sex Housing Saving accounts Checking account Purpose
# count   1000    1000             817              606    1000
# unique     2       3               4                3       8
# top     male     own          little           little     car
# freq     690     713             603              274     337

# %%
#If you have any missing values in the numerical columns try imputing those columns     
#Create a dataframe by imputing  the missing values with mean 
#Create a dataframe by imputing the missing values with median

# %%
df.isnull().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
df.mean()
# Out:
# Age                35.546
# Job                 1.904
# Credit amount    3271.258
# Duration           20.903
# dtype: float64

# %%
#Create a dataframe by imputing  the missing values with mean 
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer.fit(df[['Age']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
df[['Age']]=imputer.transform(df[['Age']])

# %%
df
# Out:
#       Age     Sex  Job Housing Saving accounts Checking account  \
# 0    67.0    male    2     own             NaN           little
# 1    22.0  female    2     own          little         moderate
# 2    49.0    male    1     own          little              NaN
# 3    45.0    male    2    free          little           little
# 4    53.0    male    2    free          little           little
# ..    ...     ...  ...     ...             ...              ...
# 995  31.0  female    1     own          little              NaN
# 996  40.0    male    3     own          little           little
# 997  38.0    male    2     own          little              NaN
# 998  23.0    male    2    free          little           little
# 999  27.0    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
#Create a dataframe by imputing the missing values with median
imputer1=SimpleImputer(missing_values=np.nan,strategy='median')

# %%
imputer1.fit(df[['Job']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
df[['Job']]=imputer1.transform(df[['Job']])

# %%
df
# Out:
#       Age     Sex  Job Housing Saving accounts Checking account  \
# 0    67.0    male  2.0     own             NaN           little
# 1    22.0  female  2.0     own          little         moderate
# 2    49.0    male  1.0     own          little              NaN
# 3    45.0    male  2.0    free          little           little
# 4    53.0    male  2.0    free          little           little
# ..    ...     ...  ...     ...             ...              ...
# 995  31.0  female  1.0     own          little              NaN
# 996  40.0    male  3.0     own          little           little
# 997  38.0    male  2.0     own          little              NaN
# 998  23.0    male  2.0    free          little           little
# 999  27.0    male  2.0     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
#If any missing values in categorical columns, impute it with mode
imputer2=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
imputer2.fit(df[['Saving accounts']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
df[['Saving accounts']]=imputer2.transform(df[['Saving accounts']])

# %%
df
# Out:
#       Age     Sex  Job Housing Saving accounts Checking account  \
# 0    67.0    male  2.0     own          little           little
# 1    22.0  female  2.0     own          little         moderate
# 2    49.0    male  1.0     own          little              NaN
# 3    45.0    male  2.0    free          little           little
# 4    53.0    male  2.0    free          little           little
# ..    ...     ...  ...     ...             ...              ...
# 995  31.0  female  1.0     own          little              NaN
# 996  40.0    male  3.0     own          little           little
# 997  38.0    male  2.0     own          little              NaN
# 998  23.0    male  2.0    free          little           little
# 999  27.0    male  2.0     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
#If any missing values in categorical columns, impute it with mode
imputer3=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
imputer3.fit(df[['Checking account']])
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='most_frequent', verbose=0)

# %%
df[['Checking account']]=imputer3.transform(df[['Checking account']])

# %%
df
# Out:
#       Age     Sex  Job Housing Saving accounts Checking account  \
# 0    67.0    male  2.0     own          little           little
# 1    22.0  female  2.0     own          little         moderate
# 2    49.0    male  1.0     own          little           little
# 3    45.0    male  2.0    free          little           little
# 4    53.0    male  2.0    free          little           little
# ..    ...     ...  ...     ...             ...              ...
# 995  31.0  female  1.0     own          little           little
# 996  40.0    male  3.0     own          little           little
# 997  38.0    male  2.0     own          little           little
# 998  23.0    male  2.0    free          little           little
# 999  27.0    male  2.0     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
#For the categorical columns apply  different kinds of encoding techniques
#label encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Saving accounts']=le.fit_transform(df['Saving accounts'])

# %%
df
# Out:
#       Age     Sex  Job Housing  Saving accounts Checking account  \
# 0    67.0    male  2.0     own                0           little
# 1    22.0  female  2.0     own                0         moderate
# 2    49.0    male  1.0     own                0           little
# 3    45.0    male  2.0    free                0           little
# 4    53.0    male  2.0    free                0           little
# ..    ...     ...  ...     ...              ...              ...
# 995  31.0  female  1.0     own                0           little
# 996  40.0    male  3.0     own                0           little
# 997  38.0    male  2.0     own                0           little
# 998  23.0    male  2.0    free                0           little
# 999  27.0    male  2.0     own                1         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
df['Checking account']=le.fit_transform(df['Checking account'])
df
# Out:
#       Age     Sex  Job Housing  Saving accounts  Checking account  \
# 0    67.0    male  2.0     own                0                 0
# 1    22.0  female  2.0     own                0                 1
# 2    49.0    male  1.0     own                0                 0
# 3    45.0    male  2.0    free                0                 0
# 4    53.0    male  2.0    free                0                 0
# ..    ...     ...  ...     ...              ...               ...
# 995  31.0  female  1.0     own                0                 0
# 996  40.0    male  3.0     own                0                 0
# 997  38.0    male  2.0     own                0                 0
# 998  23.0    male  2.0    free                0                 0
# 999  27.0    male  2.0     own                1                 1
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
# If there any duplicate values, drop the duplicate values(Do not drop from the original dataframe)
dfc=df.copy()
dfc.drop_duplicates()
# Out:
#       Age     Sex  Job Housing  Saving accounts Checking account  \
# 0    67.0    male  2.0     own                0           little
# 1    22.0  female  2.0     own                0         moderate
# 2    49.0    male  1.0     own                0           little
# 3    45.0    male  2.0    free                0           little
# 4    53.0    male  2.0    free                0           little
# ..    ...     ...  ...     ...              ...              ...
# 995  31.0  female  1.0     own                0           little
# 996  40.0    male  3.0     own                0           little
# 997  38.0    male  2.0     own                0           little
# 998  23.0    male  2.0    free                0           little
# 999  27.0    male  2.0     own                1         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]

# %%
# Visualize the columns with different kinds of plots and write the patterns you have observed.
sns.heatmap(df.isnull())

# %%
import missingno as msno
msno.matrix(df)

# %%
df.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002951BA2BD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002951B9E5248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002951BA8ECC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002951BACA408>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002951BB01508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002951BB39548>]],
#       dtype=object)

# %%
#Using boxplot, visualize the outliers if present in the dataset
plt.boxplot(df['Credit amount'])S
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2951be48508>,
#   <matplotlib.lines.Line2D at 0x2951be48cc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2951be48dc8>,
#   <matplotlib.lines.Line2D at 0x2951be4cc48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2951be42bc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2951be4cd48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2951bde8d08>],
#  'means': []}

# %%
#Identify the Output column in the dataset and divide the entire dataset into Input and Output; 
#create the training and testing datasets.
X = df.drop('Saving accounts',axis=1)
X.shape
y=df.iloc[:,0]
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (750, 8)
# (250, 8)
# (750,)
# (250,)

# %%
X_train
# Out:
#       Age     Sex  Job Housing Checking account  Credit amount  Duration  \
# 298  43.0    male  2.0     own           little           2515        18
# 160  36.0    male  2.0     own           little           2872        24
# 268  45.0    male  3.0     own           little           8978        14
# 658  28.0  female  2.0     own         moderate           4221        30
# 996  40.0    male  3.0     own           little           3857        30
# ..    ...     ...  ...     ...              ...            ...       ...
# 767  31.0  female  2.0    rent           little           2901        10
# 72   51.0    male  3.0    free           little           1164         8
# 908  46.0  female  1.0     own           little           3594        15
# 235  30.0    male  3.0     own           little           1823        24
# 37   37.0    male  2.0     own             rich           2100        18
#
#                  Purpose
# 298  furniture/equipment
# 160             radio/TV
# 268                  car
# 658             business
# 996                  car
# ..                   ...
# 767                  car
# 72       vacation/others
# 908                  car
# 235             radio/TV
# 37              radio/TV
#
# [750 rows x 8 columns]

# %%
y_train
# Out:
# 298    43.0
# 160    36.0
# 268    45.0
# 658    28.0
# 996    40.0
#        ...
# 767    31.0
# 72     51.0
# 908    46.0
# 235    30.0
# 37     37.0
# Name: Age, Length: 750, dtype: float64

# %%
df
# Out:
#       Age     Sex  Job Housing  Saving accounts Checking account  \
# 0    67.0    male  2.0     own                0           little
# 1    22.0  female  2.0     own                0         moderate
# 2    49.0    male  1.0     own                0           little
# 3    45.0    male  2.0    free                0           little
# 4    53.0    male  2.0    free                0           little
# ..    ...     ...  ...     ...              ...              ...
# 995  31.0  female  1.0     own                0           little
# 996  40.0    male  3.0     own                0           little
# 997  38.0    male  2.0     own                0           little
# 998  23.0    male  2.0    free                0           little
# 999  27.0    male  2.0     own                1         moderate
#
#      Credit amount  Duration              Purpose
# 0             1169         6             radio/TV
# 1             5951        48             radio/TV
# 2             2096        12            education
# 3             7882        42  furniture/equipment
# 4             4870        24                  car
# ..             ...       ...                  ...
# 995           1736        12  furniture/equipment
# 996           3857        30                  car
# 997            804        12             radio/TV
# 998           1845        45             radio/TV
# 999           4576        45                  car
#
# [1000 rows x 9 columns]
